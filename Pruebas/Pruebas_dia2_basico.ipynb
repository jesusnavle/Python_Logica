# %% [markdown]
# ##Dia 2 Pruebas python

# %% [markdown]
# Ejercicio 6: El Primer Carácter Único
# Escribe una función que reciba una cadena y devuelva el índice del primer carácter que no se repite. Si todos se repiten, devuelve -1.
#
# Entrada: "loveleetcode"
#
# Salida: 2 (La 'v' es la primera que no se repite).

# %%
entrada = 'loveleetcode'
contador = 0
for contador in entrada:
    contador += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2 contador = 0
#       3 for contador in list(entrada):
# ----> 4     contador += 1
#
# TypeError: can only concatenate str (not "int") to str
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.
